# %%
import __future__
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
titanic_train = pd.read_csv('Titanic-Dataset.csv')
titanic_train.head(10)# Check out the first 10 rows of the training dataset
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
titanic_train.info()# Info about data frame dimensions, column types, and file size
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic_train.describe()# Generate a summary of statistics for each numerical column of the data frame
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_train.nunique()#print the total coloum And name
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
#find colums have less than 10 unique values
lessthanten = []
for col in titanic_train.columns:
    lessthanten.append(titanic_train[col].nunique() < 10)

for col in titanic_train[titanic_train.columns[lessthanten]]:
    print(col, titanic_train[col].unique())
# Out:
# Survived [0 1]
# Pclass [3 1 2]
# Sex ['male' 'female']
# SibSp [1 0 3 4 2 5 8]
# Parch [0 1 2 5 3 4 6]
# Embarked ['S' 'C' 'Q' nan]

# %%
titanic_train['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
#differentiate the variables as follows, and produce a dataframe to put them into a table.
pd.DataFrame({'Integer': ['Survived','Pclass','SibSp, Parch','-'], 
              'Float': ['-','-','-','Age, Fare'], 
              'Object': ['Sex, Name, Ticket, Cabin, Embarked','-','-','-']}, 
              index = ['Nominal','Ordinal','Discrete','Continuous'])
# Out:
#                  Integer      Float                              Object
# Nominal         Survived          -  Sex, Name, Ticket, Cabin, Embarked
# Ordinal           Pclass          -                                   -
# Discrete    SibSp, Parch          -                                   -
# Continuous             -  Age, Fare                                   -

# %%
titanic_train.head(10)# First 10 rows of the data
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
# Define the count_n_plot function
def count_n_plot(df, col_name, countsplit = None, bar = False, barsplit = None):
    
    """
    Creates countplots and barplots of the specified feature 
    (with options to split the columns) and generates the 
    corresponding table of counts and percentages.
    
    Parameters
    ----------
    df : DataFrame
        Dataset for plotting.
    col_name : string
        Name of column/feature in "data".
    countsplit : string
        Use countsplit to specify the "hue" argument of the countplot.
    bar : Boolean
        If True, a barplot of the column col_name is created, showing
        the fraction of survivors on the y-axis.
    barsplit: string
        Use barsplit to specify the "hue" argument of the barplot.
    """
    
    if (countsplit != None) & bar & (barsplit != None):
        col_count1 = df[[col_name]].groupby(by = col_name).size()
        col_perc1 = col_count1.apply(lambda x: x / sum(col_count1) * 100).round(1)
        tcount1 = pd.DataFrame({'Count': col_count1, 'Percentage': col_perc1})
        
        col_count2 = df[[col_name,countsplit]].groupby(by = [col_name,countsplit]).size()
        col_perc2 = col_count2.apply(lambda x: x / sum(col_count2) * 100).round(1)
        tcount2 = pd.DataFrame({'Count': col_count2, 'Percentage': col_perc2})
        display(tcount1, tcount2) 
        
        figc, axc = plt.subplots(1, 2, figsize = (10,4))
        sns.countplot(data = df, x = col_name, hue = None, ax = axc[0])
        sns.countplot(data = df, x = col_name, hue = countsplit, ax = axc[1])
        
        figb, axb = plt.subplots(1, 2, figsize = (10,4))
        sns.barplot(data = df, x = col_name, y = 'Survived', hue = None, ax = axb[0])
        sns.barplot(data = df, x = col_name, y = 'Survived', hue = barsplit, ax = axb[1])
        
    elif (countsplit != None) & bar:
        col_count1 = df[[col_name]].groupby(by = col_name).size()
        col_perc1 = col_count1.apply(lambda x: x / sum(col_count1) * 100).round(1)
        tcount1 = pd.DataFrame({'Count': col_count1, 'Percentage': col_perc1})
        
        col_count2 = df[[col_name,countsplit]].groupby(by = [col_name,countsplit]).size()
        col_perc2 = col_count2.apply(lambda x: x / sum(col_count2) * 100).round(1)
        tcount2 = pd.DataFrame({'Count': col_count2, 'Percentage': col_perc2})
        display(tcount1, tcount2)
        
        fig, axes = plt.subplots(1, 3, figsize = (15,4))
        sns.countplot(data = df, x = col_name, hue = None, ax = axes[0])
        sns.countplot(data = df, x = col_name, hue = countsplit, ax = axes[1])
        sns.barplot(data = df, x = col_name, y = 'Survived', hue = None, ax = axes[2])
        
    elif countsplit != None:
        col_count1 = df[[col_name]].groupby(by = col_name).size()
        col_perc1 = col_count1.apply(lambda x: x / sum(col_count1) * 100).round(1)
        tcount1 = pd.DataFrame({'Count': col_count1, 'Percentage': col_perc1})
        
        col_count2 = df[[col_name,countsplit]].groupby(by = [col_name,countsplit]).size()
        col_perc2 = col_count2.apply(lambda x: x / sum(col_count2) * 100).round(1)
        tcount2 = pd.DataFrame({'Count': col_count2, 'Percentage': col_perc2})
        display(tcount1, tcount2)
        
        fig, axes = plt.subplots(1, 2, figsize = (10,4))
        sns.countplot(data = df, x = col_name, hue = None, ax = axes[0])
        sns.countplot(data = df, x = col_name, hue = countsplit, ax = axes[1])
        
    else:
        col_count = df[[col_name]].groupby(by = col_name).size()
        col_perc = col_count.apply(lambda x: x / sum(col_count) * 100).round(1)
        tcount1 = pd.DataFrame({'Count': col_count, 'Percentage': col_perc})
        display(tcount1)        
        
        sns.countplot(data = df, x = col_name)

# %%
#Use count_n_plot to see the overall survival rate (which is not an actual rate but a percentage):
count_n_plot(df = titanic_train, col_name = 'Survived')
# Out:
#           Count  Percentage
# Survived
# 0           549        61.6
# 1           342        38.4

# %%
count_n_plot(df = titanic_train, col_name = 'Pclass', countsplit = 'Survived')#give the graph view of survived,count,precentage
# Out:
#         Count  Percentage
# Pclass
# 1         216        24.2
# 2         184        20.7
# 3         491        55.1
#                  Count  Percentage
# Pclass Survived
# 1      0            80         9.0
#        1           136        15.3
# 2      0            97        10.9
#        1            87         9.8
# 3      0           372        41.8
#        1           119        13.4

# %%
count_n_plot(df = titanic_train, col_name = 'Pclass', countsplit = 'Survived', bar = True)#give the graph view of Pclass,count,precentage
# Out:
#         Count  Percentage
# Pclass
# 1         216        24.2
# 2         184        20.7
# 3         491        55.1
#                  Count  Percentage
# Pclass Survived
# 1      0            80         9.0
#        1           136        15.3
# 2      0            97        10.9
#        1            87         9.8
# 3      0           372        41.8
#        1           119        13.4

# %%
count_n_plot(df = titanic_train, col_name = 'Sex', countsplit = 'Survived', bar = True)#give the graph view of sex,count,precentage
# Out:
#         Count  Percentage
# Sex
# female    314        35.2
# male      577        64.8
#                  Count  Percentage
# Sex    Survived
# female 0            81         9.1
#        1           233        26.2
# male   0           468        52.5
#        1           109        12.2

# %%
count_n_plot(df = titanic_train, col_name = 'Sex', countsplit = 'Pclass', bar = True, barsplit = 'Pclass')#give the graph view of sex,count,precentage
# Out:
#         Count  Percentage
# Sex
# female    314        35.2
# male      577        64.8
#                Count  Percentage
# Sex    Pclass
# female 1          94        10.5
#        2          76         8.5
#        3         144        16.2
# male   1         122        13.7
#        2         108        12.1
#        3         347        38.9

# %%
count_n_plot(df = titanic_train, col_name = 'Embarked', countsplit = 'Survived', bar = True)
# Out:
#           Count  Percentage
# Embarked
# C           168        18.9
# Q            77         8.7
# S           644        72.4
#                    Count  Percentage
# Embarked Survived
# C        0            75         8.4
#          1            93        10.5
# Q        0            47         5.3
#          1            30         3.4
# S        0           427        48.0
#          1           217        24.4

# %%
count_n_plot(df = titanic_train, col_name = 'Embarked', countsplit = 'Sex', bar = True, barsplit = 'Sex')
# Out:
#           Count  Percentage
# Embarked
# C           168        18.9
# Q            77         8.7
# S           644        72.4
#                  Count  Percentage
# Embarked Sex
# C        female     73         8.2
#          male       95        10.7
# Q        female     36         4.0
#          male       41         4.6
# S        female    203        22.8
#          male      441        49.6

# %%
count_n_plot(df = titanic_train, col_name = 'Embarked', countsplit = 'Pclass', bar = True, barsplit = 'Pclass')
# Out:
#           Count  Percentage
# Embarked
# C           168        18.9
# Q            77         8.7
# S           644        72.4
#                  Count  Percentage
# Embarked Pclass
# C        1          85         9.6
#          2          17         1.9
#          3          66         7.4
# Q        1           2         0.2
#          2           3         0.3
#          3          72         8.1
# S        1         127        14.3
#          2         164        18.4
#          3         353        39.7

# %%
count_n_plot(df = titanic_train, col_name = 'SibSp', countsplit = 'Survived', bar = True, barsplit = 'Sex')
# Out:
#        Count  Percentage
# SibSp
# 0        608        68.2
# 1        209        23.5
# 2         28         3.1
# 3         16         1.8
# 4         18         2.0
# 5          5         0.6
# 8          7         0.8
#                 Count  Percentage
# SibSp Survived
# 0     0           398        44.7
#       1           210        23.6
# 1     0            97        10.9
#       1           112        12.6
# 2     0            15         1.7
#       1            13         1.5
# 3     0            12         1.3
#       1             4         0.4
# 4     0            15         1.7
#       1             3         0.3
# 5     0             5         0.6
# 8     0             7         0.8

# %%
count_n_plot(df = titanic_train, col_name = 'Parch', countsplit = 'Survived', bar = True, barsplit = 'Sex')
# Out:
#        Count  Percentage
# Parch
# 0        678        76.1
# 1        118        13.2
# 2         80         9.0
# 3          5         0.6
# 4          4         0.4
# 5          5         0.6
# 6          1         0.1
#                 Count  Percentage
# Parch Survived
# 0     0           445        49.9
#       1           233        26.2
# 1     0            53         5.9
#       1            65         7.3
# 2     0            40         4.5
#       1            40         4.5
# 3     0             2         0.2
#       1             3         0.3
# 4     0             4         0.4
# 5     0             4         0.4
#       1             1         0.1
# 6     0             1         0.1

# %%
titanic_train.isnull().sum()*100 / len(titanic_train)
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
titanic_train[titanic_train['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 5      male  NaN      0      0      330877   8.4583   NaN        Q
# 17     male  NaN      0      0      244373  13.0000   NaN        S
# 19   female  NaN      0      0        2649   7.2250   NaN        C
# 26     male  NaN      0      0        2631   7.2250   NaN        C
# 28   female  NaN      0      0      330959   7.8792   NaN        Q
# ..      ...  ...    ...    ...         ...      ...   ...      ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S
# 868    male  NaN      0      0      345777   9.5000   NaN        S
# 878    male  NaN      0      0      349217   7.8958   NaN        S
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S
#
# [177 rows x 12 columns]

# %%
mean_age = round(titanic_train['Age'].mean(), 1)
print(mean_age)
# Out:
# 29.7

# %%
titanic_train['Age'].replace(np.nan, mean_age)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    29.7
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
# iloc means index location
titanic_train.iloc[[5,19,28,863,878],:]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 5              6         0       3                   Moran, Mr. James    male
# 19            20         1       3            Masselmani, Mrs. Fatima  female
# 28            29         1       3      O'Dwyer, Miss. Ellen "Nellie"  female
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
# 878          879         0       3                 Laleff, Mr. Kristo    male
#
#      Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 5    NaN      0      0    330877   8.4583   NaN        Q
# 19   NaN      0      0      2649   7.2250   NaN        C
# 28   NaN      0      0    330959   7.8792   NaN        Q
# 863  NaN      8      2  CA. 2343  69.5500   NaN        S
# 878  NaN      0      0    349217   7.8958   NaN        S

# %%
mode_embarked = titanic_train['Embarked'].mode()[0] 
print(mode_embarked)
# Out:
# S

# %%
print(type(titanic_train['Embarked'].mode()))
print(type(titanic_train['Embarked'].mode()[0]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'str'>

# %%
# look at missing values for Embarked column
titanic_train[titanic_train['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
# check if replaced correctly
titanic_train.iloc[[61,829],:]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
titanic_train.drop(columns='Cabin', inplace=True)

# %%
# Check new dataset
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
titanic_train.drop(columns=['PassengerId','Name','Ticket','Embarked'], inplace=True)

# %%
titanic_train.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0         0       3    male  22.0      1      0   7.2500
# 1         1       1  female  38.0      1      0  71.2833
# 2         1       3  female  26.0      0      0   7.9250
# 3         1       1  female  35.0      1      0  53.1000
# 4         0       3    male  35.0      0      0   8.0500

# %%
titanic_train = pd.get_dummies(titanic_train, columns=['Sex'])

# %%
titanic_train.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male
# 0         0       3  22.0      1      0   7.2500       False      True
# 1         1       1  38.0      1      0  71.2833        True     False
# 2         1       3  26.0      0      0   7.9250        True     False
# 3         1       1  35.0      1      0  53.1000        True     False
# 4         0       3  35.0      0      0   8.0500       False      True

# %%
# Drop Sex_female
titanic_train.drop('Sex_female', axis=1, inplace=True)

# %%
titanic_train.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_male
# 0         0       3  22.0      1      0   7.2500      True
# 1         1       1  38.0      1      0  71.2833     False
# 2         1       3  26.0      0      0   7.9250     False
# 3         1       1  35.0      1      0  53.1000     False
# 4         0       3  35.0      0      0   8.0500      True

# %%
titanic_train = pd.get_dummies(titanic_train, columns=['Pclass'], drop_first=True)

# %%
titanic_train.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare  Sex_male  Pclass_2  Pclass_3
# 0         0  22.0      1      0   7.2500      True     False      True
# 1         1  38.0      1      0  71.2833     False     False     False
# 2         1  26.0      0      0   7.9250     False     False      True
# 3         1  35.0      1      0  53.1000     False     False     False
# 4         0  35.0      0      0   8.0500      True     False      True

# %%
# Read in the test dataset
titanic_test = pd.read_csv('Titanic-Dataset.csv')

# %%
# Inspect the test dataset
titanic_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Check for null values
titanic_test.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Cleaning Age column
mean_age_test = titanic_test['Age'].mean()
print(mean_age_test)
# Out:
# 29.69911764705882

# %%
titanic_test['Age'].replace(np.nan, mean_age_test)
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
# Cleaning Fare column
mean_fare_test = titanic_test['Fare'].mean()
print(mean_fare_test)
# Out:
# 32.204207968574636

# %%
titanic_test['Fare'].replace(np.nan, mean_fare_test)
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
# Remove irrelevant columns but keep a copy of PassengerId column
eye_dee = titanic_test['PassengerId']
titanic_test.drop(columns=['PassengerId','Name','Ticket','Cabin','Embarked'], inplace=True)

# %%
titanic_test.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0         0       3    male  22.0      1      0   7.2500
# 1         1       1  female  38.0      1      0  71.2833
# 2         1       3  female  26.0      0      0   7.9250
# 3         1       1  female  35.0      1      0  53.1000
# 4         0       3    male  35.0      0      0   8.0500

# %%
titanic_test.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# dtype: int64

# %%
# One-hot encoding Pclass and Sex
titanic_test = pd.get_dummies(data=titanic_test, columns=['Pclass','Sex'], drop_first=True)

# %%
titanic_test.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare  Pclass_2  Pclass_3  Sex_male
# 0         0  22.0      1      0   7.2500     False      True      True
# 1         1  38.0      1      0  71.2833     False     False     False
# 2         1  26.0      0      0   7.9250     False      True     False
# 3         1  35.0      1      0  53.1000     False     False     False
# 4         0  35.0      0      0   8.0500     False      True      True

# %%
# independent varibles, represented by a capital X; dependent variables represented by lowercase y
# [:,1:] means select all rows, and columns from 1st column onwards
X_train = titanic_train.iloc[:,1:]
y_train = titanic_train['Survived']
X_test = titanic_test

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Specify the optimisation algorithm as 'lbfgs' (to silence the warning)
logistic_model = LogisticRegression(solver='lbfgs')

# %%
logistic_model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 pred = logistic_model.predict(X_test)
#
# File c:\Users\Aditya\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_base.py:375, in LinearClassifierMixin.predict(self, X)
#     361 """
#     362 Predict class labels for samples in X.
#     363
#    (...)    372     Vector containing the class labels for each sample.
#     373 """
#     374 xp, _ = get_namespace(X)
# --> 375 scores = self.decision_function(X)
#     376 if len(scores.shape) == 1:
#     377     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# File c:\Users\Aditya\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_base.py:352, in LinearClassifierMixin.decision_function(self, X)
#     349 check_is_fitted(self)
#     350 xp, _ = get_namespace(X)
# --> 352 X = validate_data(self, X, accept_sparse="csr", reset=False)
#     353 scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     354 return (
#     355     xp.reshape(scores, (-1,))
#     356     if (scores.ndim > 1 and scores.shape[1] == 1)
#     357     else scores
#     358 )
#
# File c:\Users\Aditya\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2929, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2845 def validate_data(
#    2846     _estimator,
#    2847     /,
#    (...)   2853     **check_params,
#    2854 ):
#    2855     """Validate input data and set or check feature names and counts of the input.
#    2856
#    2857     This helper function should be used in an estimator that requires input
#    (...)   2927         validated.
#    2928     """
# -> 2929     _check_feature_names(_estimator, X, reset=reset)
#    2930     tags = get_tags(_estimator)
#    2931     if y is None and tags.target_tags.required:
#
# File c:\Users\Aditya\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2787, in _check_feature_names(estimator, X, reset)
#    2784 if not missing_names and not unexpected_names:
#    2785     message += "Feature names must be in the same order as they were in fit.\n"
# -> 2787 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - Survived
